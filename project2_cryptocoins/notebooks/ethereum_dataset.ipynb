# %% [markdown]
# ### Masive Data Assignment
#  (second project)
# Read, Clean, and prepare the Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### ethereum_dataset

# %% [markdown]
# #### 1. Read the Data

# %%
# Read Bitcoin dataset 
df = pd.read_csv('../data/raw/ethereum_dataset.csv', parse_dates = ['Date(UTC)'])
df.head()
# Out:
#    Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 0 2015-07-30     1438214400             0.0    8893         9205
# 1 2015-07-31     1438300800             0.0       0         9361
# 2 2015-08-01     1438387200             0.0       0         9476
# 3 2015-08-02     1438473600             0.0       0         9563
# 4 2015-08-03     1438560000             0.0       0         9639
#
#      eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 0  7.204931e+07            0.0       23.7569           0.121        6912
# 1  7.208550e+07            0.0       48.1584           0.603        6863
# 2  7.211320e+07            0.0       55.2709           0.887        5293
# 3  7.214143e+07            0.0       64.1779           1.020        5358
# 4  7.216940e+07            0.0       69.8559           1.126        5280
#
#    eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %%
df.columns
# Out:
# Index(['Date(UTC)', 'UnixTimeStamp', 'eth_etherprice', 'eth_tx', 'eth_address',
#        'eth_supply', 'eth_marketcap', 'eth_hashrate', 'eth_difficulty',
#        'eth_blocks', 'eth_uncles', 'eth_blocksize', 'eth_blocktime',
#        'eth_gasprice', 'eth_gaslimit', 'eth_gasused', 'eth_ethersupply',
#        'eth_chaindatasize', 'eth_ens_register'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date(UTC)              0
# UnixTimeStamp          0
# eth_etherprice         0
# eth_tx                 0
# eth_address            0
# eth_supply             0
# eth_marketcap          0
# eth_hashrate           0
# eth_difficulty         0
# eth_blocks             0
# eth_uncles             0
# eth_blocksize          0
# eth_blocktime          0
# eth_gasprice           0
# eth_gaslimit           0
# eth_gasused            0
# eth_ethersupply        0
# eth_chaindatasize    769
# eth_ens_register     644
# dtype: int64

# %%
df.count()
# Out:
# Date(UTC)            769
# UnixTimeStamp        769
# eth_etherprice       769
# eth_tx               769
# eth_address          769
# eth_supply           769
# eth_marketcap        769
# eth_hashrate         769
# eth_difficulty       769
# eth_blocks           769
# eth_uncles           769
# eth_blocksize        769
# eth_blocktime        769
# eth_gasprice         769
# eth_gaslimit         769
# eth_gasused          769
# eth_ethersupply      769
# eth_chaindatasize      0
# eth_ens_register     125
# dtype: int64

# %% [markdown]
# as we can see we have in this data set 19 columns and each column has 769 cells, but we have missing data in eth_chaindatasize and eth_ens_register columns, (empty cells)

# %%
df.describe()
# Out:
#        UnixTimeStamp  eth_etherprice         eth_tx   eth_address  \
# count   7.690000e+02      769.000000     769.000000  7.690000e+02
# mean    1.471392e+09       46.920806   70564.308192  1.050655e+06
# std     1.919250e+07       90.378356   89424.024060  1.521229e+06
# min     1.438214e+09        0.000000       0.000000  9.205000e+03
# 25%     1.454803e+09        2.520000   17549.000000  5.892500e+04
# 50%     1.471392e+09       10.970000   42346.000000  5.394280e+05
# 75%     1.487981e+09       14.990000   58756.000000  1.081093e+06
# max     1.504570e+09      394.660000  444413.000000  7.067860e+06
#
#          eth_supply  eth_marketcap  eth_hashrate  eth_difficulty   eth_blocks  \
# count  7.690000e+02     769.000000    769.000000      769.000000   769.000000
# mean   8.320820e+07    4301.621649  13247.782131      233.619406  5517.196359
# std    6.753548e+06    8451.186405  22419.039496      455.312190   627.739112
# ...

# %%
# General Information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 19 columns):
# Date(UTC)            769 non-null datetime64[ns]
# UnixTimeStamp        769 non-null int64
# eth_etherprice       769 non-null float64
# eth_tx               769 non-null int64
# eth_address          769 non-null int64
# eth_supply           769 non-null float64
# eth_marketcap        769 non-null float64
# eth_hashrate         769 non-null float64
# eth_difficulty       769 non-null float64
# eth_blocks           769 non-null int64
# eth_uncles           769 non-null int64
# eth_blocksize        769 non-null int64
# eth_blocktime        769 non-null float64
# eth_gasprice         769 non-null int64
# eth_gaslimit         769 non-null int64
# eth_gasused          769 non-null int64
# eth_ethersupply      769 non-null float64
# eth_chaindatasize    0 non-null float64
# eth_ens_register     125 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(9)
# ...

# %%
#check if the dataset is duplicated
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 764    False
# 765    False
# 766    False
# 767    False
# 768    False
# Length: 769, dtype: bool

# %% [markdown]
# #### 2. Cleaning Data

# %%
# Replacing missing data with NaN
df.replace(' ', np.nan,inplace=True)
df[df['eth_chaindatasize'].isnull()].head()
# Out:
#    Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 0 2015-07-30     1438214400             0.0    8893         9205
# 1 2015-07-31     1438300800             0.0       0         9361
# 2 2015-08-01     1438387200             0.0       0         9476
# 3 2015-08-02     1438473600             0.0       0         9563
# 4 2015-08-03     1438560000             0.0       0         9639
#
#      eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 0  7.204931e+07            0.0       23.7569           0.121        6912
# 1  7.208550e+07            0.0       48.1584           0.603        6863
# 2  7.211320e+07            0.0       55.2709           0.887        5293
# 3  7.214143e+07            0.0       64.1779           1.020        5358
# 4  7.216940e+07            0.0       69.8559           1.126        5280
#
#    eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %%
# Replacing missing data with NaN
df.replace(' ', np.nan,inplace=True)
df[df['eth_ens_register'].isnull()].head()
# Out:
#    Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 0 2015-07-30     1438214400             0.0    8893         9205
# 1 2015-07-31     1438300800             0.0       0         9361
# 2 2015-08-01     1438387200             0.0       0         9476
# 3 2015-08-02     1438473600             0.0       0         9563
# 4 2015-08-03     1438560000             0.0       0         9639
#
#      eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 0  7.204931e+07            0.0       23.7569           0.121        6912
# 1  7.208550e+07            0.0       48.1584           0.603        6863
# 2  7.211320e+07            0.0       55.2709           0.887        5293
# 3  7.214143e+07            0.0       64.1779           1.020        5358
# 4  7.216940e+07            0.0       69.8559           1.126        5280
#
#    eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 19 columns):
# Date(UTC)            769 non-null datetime64[ns]
# UnixTimeStamp        769 non-null int64
# eth_etherprice       769 non-null float64
# eth_tx               769 non-null int64
# eth_address          769 non-null int64
# eth_supply           769 non-null float64
# eth_marketcap        769 non-null float64
# eth_hashrate         769 non-null float64
# eth_difficulty       769 non-null float64
# eth_blocks           769 non-null int64
# eth_uncles           769 non-null int64
# eth_blocksize        769 non-null int64
# eth_blocktime        769 non-null float64
# eth_gasprice         769 non-null int64
# eth_gaslimit         769 non-null int64
# eth_gasused          769 non-null int64
# eth_ethersupply      769 non-null float64
# eth_chaindatasize    0 non-null float64
# eth_ens_register     125 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(9)
# ...

# %% [markdown]
# #### 3. dealing with missing data

# %%
#newdf without NaN value
newdf = df[np.isfinite(df['eth_chaindatasize'])]
newdf.tail()
# Out:
# Empty DataFrame
# Columns: [Date(UTC), UnixTimeStamp, eth_etherprice, eth_tx, eth_address, eth_supply, eth_marketcap, eth_hashrate, eth_difficulty, eth_blocks, eth_uncles, eth_blocksize, eth_blocktime, eth_gasprice, eth_gaslimit, eth_gasused, eth_ethersupply, eth_chaindatasize, eth_ens_register]
# Index: []

# %%
# correlation between columns
correlation = df.corr(method="pearson")
correlation
# Out:
#                    UnixTimeStamp  eth_etherprice    eth_tx  eth_address  \
# UnixTimeStamp           1.000000        0.652518  0.755958     0.780440
# eth_etherprice          0.652518        1.000000  0.905125     0.854466
# eth_tx                  0.755958        0.905125  1.000000     0.968595
# eth_address             0.780440        0.854466  0.968595     1.000000
# eth_supply              0.999488        0.651965  0.751958     0.778211
# eth_marketcap           0.650814        0.999941  0.906244     0.857059
# eth_hashrate            0.726065        0.878703  0.971590     0.992536
# eth_difficulty          0.666372        0.832209  0.952171     0.982819
# eth_blocks              0.062836       -0.468618 -0.470719    -0.495091
# eth_uncles             -0.037962       -0.098251 -0.104439    -0.147153
# eth_blocksize           0.668148        0.856449  0.973135     0.958496
# eth_blocktime           0.029136        0.478762  0.520930     0.561703
# ...

# %% [markdown]
# #### 4. Data Visualization

# %%
# plot using histograms
df.hist(figsize=(15,20))
plt.figure()
