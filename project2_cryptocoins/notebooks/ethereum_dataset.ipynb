# %% [markdown]
# ### Masive Data Assignment
#  (second project)
# Read, Clean, and prepare the Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### ethereum_dataset

# %% [markdown]
# #### 1. Read the Data

# %%
# Read Bitcoin dataset 
df = pd.read_csv('../data/raw/ethereum_dataset.csv', parse_dates = ['Date(UTC)'])
df.head()
# Out:
#    Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 0 2015-07-30     1438214400             0.0    8893         9205
# 1 2015-07-31     1438300800             0.0       0         9361
# 2 2015-08-01     1438387200             0.0       0         9476
# 3 2015-08-02     1438473600             0.0       0         9563
# 4 2015-08-03     1438560000             0.0       0         9639
#
#      eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 0  7.204931e+07            0.0       23.7569           0.121        6912
# 1  7.208550e+07            0.0       48.1584           0.603        6863
# 2  7.211320e+07            0.0       55.2709           0.887        5293
# 3  7.214143e+07            0.0       64.1779           1.020        5358
# 4  7.216940e+07            0.0       69.8559           1.126        5280
#
#    eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %%
df.columns
# Out:
# Index(['Date(UTC)', 'UnixTimeStamp', 'eth_etherprice', 'eth_tx', 'eth_address',
#        'eth_supply', 'eth_marketcap', 'eth_hashrate', 'eth_difficulty',
#        'eth_blocks', 'eth_uncles', 'eth_blocksize', 'eth_blocktime',
#        'eth_gasprice', 'eth_gaslimit', 'eth_gasused', 'eth_ethersupply',
#        'eth_chaindatasize', 'eth_ens_register'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date(UTC)              0
# UnixTimeStamp          0
# eth_etherprice         0
# eth_tx                 0
# eth_address            0
# eth_supply             0
# eth_marketcap          0
# eth_hashrate           0
# eth_difficulty         0
# eth_blocks             0
# eth_uncles             0
# eth_blocksize          0
# eth_blocktime          0
# eth_gasprice           0
# eth_gaslimit           0
# eth_gasused            0
# eth_ethersupply        0
# eth_chaindatasize    769
# eth_ens_register     644
# dtype: int64

# %%
df.count()
# Out:
# Date(UTC)            769
# UnixTimeStamp        769
# eth_etherprice       769
# eth_tx               769
# eth_address          769
# eth_supply           769
# eth_marketcap        769
# eth_hashrate         769
# eth_difficulty       769
# eth_blocks           769
# eth_uncles           769
# eth_blocksize        769
# eth_blocktime        769
# eth_gasprice         769
# eth_gaslimit         769
# eth_gasused          769
# eth_ethersupply      769
# eth_chaindatasize      0
# eth_ens_register     125
# dtype: int64

# %% [markdown]
# as we can see we have in this data set 19 columns and each column has 769 cells, but we have missing data in eth_chaindatasize and eth_ens_register columns, (empty cells)

# %%
df.describe()
# Out:
#        UnixTimeStamp  eth_etherprice         eth_tx   eth_address  \
# count   7.690000e+02      769.000000     769.000000  7.690000e+02
# mean    1.471392e+09       46.920806   70564.308192  1.050655e+06
# std     1.919250e+07       90.378356   89424.024060  1.521229e+06
# min     1.438214e+09        0.000000       0.000000  9.205000e+03
# 25%     1.454803e+09        2.520000   17549.000000  5.892500e+04
# 50%     1.471392e+09       10.970000   42346.000000  5.394280e+05
# 75%     1.487981e+09       14.990000   58756.000000  1.081093e+06
# max     1.504570e+09      394.660000  444413.000000  7.067860e+06
#
#          eth_supply  eth_marketcap  eth_hashrate  eth_difficulty   eth_blocks  \
# count  7.690000e+02     769.000000    769.000000      769.000000   769.000000
# mean   8.320820e+07    4301.621649  13247.782131      233.619406  5517.196359
# std    6.753548e+06    8451.186405  22419.039496      455.312190   627.739112
# ...

# %%
# General Information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 19 columns):
# Date(UTC)            769 non-null datetime64[ns]
# UnixTimeStamp        769 non-null int64
# eth_etherprice       769 non-null float64
# eth_tx               769 non-null int64
# eth_address          769 non-null int64
# eth_supply           769 non-null float64
# eth_marketcap        769 non-null float64
# eth_hashrate         769 non-null float64
# eth_difficulty       769 non-null float64
# eth_blocks           769 non-null int64
# eth_uncles           769 non-null int64
# eth_blocksize        769 non-null int64
# eth_blocktime        769 non-null float64
# eth_gasprice         769 non-null int64
# eth_gaslimit         769 non-null int64
# eth_gasused          769 non-null int64
# eth_ethersupply      769 non-null float64
# eth_chaindatasize    0 non-null float64
# eth_ens_register     125 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(9)
# ...

# %%
#check if the dataset is duplicated
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 764    False
# 765    False
# 766    False
# 767    False
# 768    False
# Length: 769, dtype: bool

# %% [markdown]
# #### 2. Cleaning Data

# %%
# Replacing missing data with NaN
df.replace(' ', np.nan,inplace=True)
df[df['eth_chaindatasize'].isnull()].head()
# Out:
#    Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 0 2015-07-30     1438214400             0.0    8893         9205
# 1 2015-07-31     1438300800             0.0       0         9361
# 2 2015-08-01     1438387200             0.0       0         9476
# 3 2015-08-02     1438473600             0.0       0         9563
# 4 2015-08-03     1438560000             0.0       0         9639
#
#      eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 0  7.204931e+07            0.0       23.7569           0.121        6912
# 1  7.208550e+07            0.0       48.1584           0.603        6863
# 2  7.211320e+07            0.0       55.2709           0.887        5293
# 3  7.214143e+07            0.0       64.1779           1.020        5358
# 4  7.216940e+07            0.0       69.8559           1.126        5280
#
#    eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %%
# Replacing missing data with NaN
df.replace(' ', np.nan,inplace=True)
df[df['eth_ens_register'].isnull()].head()
# Out:
#    Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 0 2015-07-30     1438214400             0.0    8893         9205
# 1 2015-07-31     1438300800             0.0       0         9361
# 2 2015-08-01     1438387200             0.0       0         9476
# 3 2015-08-02     1438473600             0.0       0         9563
# 4 2015-08-03     1438560000             0.0       0         9639
#
#      eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 0  7.204931e+07            0.0       23.7569           0.121        6912
# 1  7.208550e+07            0.0       48.1584           0.603        6863
# 2  7.211320e+07            0.0       55.2709           0.887        5293
# 3  7.214143e+07            0.0       64.1779           1.020        5358
# 4  7.216940e+07            0.0       69.8559           1.126        5280
#
#    eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 19 columns):
# Date(UTC)            769 non-null datetime64[ns]
# UnixTimeStamp        769 non-null int64
# eth_etherprice       769 non-null float64
# eth_tx               769 non-null int64
# eth_address          769 non-null int64
# eth_supply           769 non-null float64
# eth_marketcap        769 non-null float64
# eth_hashrate         769 non-null float64
# eth_difficulty       769 non-null float64
# eth_blocks           769 non-null int64
# eth_uncles           769 non-null int64
# eth_blocksize        769 non-null int64
# eth_blocktime        769 non-null float64
# eth_gasprice         769 non-null int64
# eth_gaslimit         769 non-null int64
# eth_gasused          769 non-null int64
# eth_ethersupply      769 non-null float64
# eth_chaindatasize    0 non-null float64
# eth_ens_register     125 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(9)
# ...

# %% [markdown]
# #### 3. dealing with missing data

# %%
#newdf without NaN value
newdf = df[np.isfinite(df['eth_chaindatasize'])]
newdf.tail()
# Out:
# Empty DataFrame
# Columns: [Date(UTC), UnixTimeStamp, eth_etherprice, eth_tx, eth_address, eth_supply, eth_marketcap, eth_hashrate, eth_difficulty, eth_blocks, eth_uncles, eth_blocksize, eth_blocktime, eth_gasprice, eth_gaslimit, eth_gasused, eth_ethersupply, eth_chaindatasize, eth_ens_register]
# Index: []

# %%
# correlation between columns
correlation = newdf.corr(method="pearson")
correlation
# Out:
#                    UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# UnixTimeStamp                NaN             NaN     NaN          NaN
# eth_etherprice               NaN             NaN     NaN          NaN
# eth_tx                       NaN             NaN     NaN          NaN
# eth_address                  NaN             NaN     NaN          NaN
# eth_supply                   NaN             NaN     NaN          NaN
# eth_marketcap                NaN             NaN     NaN          NaN
# eth_hashrate                 NaN             NaN     NaN          NaN
# eth_difficulty               NaN             NaN     NaN          NaN
# eth_blocks                   NaN             NaN     NaN          NaN
# eth_uncles                   NaN             NaN     NaN          NaN
# eth_blocksize                NaN             NaN     NaN          NaN
# eth_blocktime                NaN             NaN     NaN          NaN
# ...

# %%
import matplotlib.pyplot as plt
def plot_data(xdata,ydata,xlabel):
    plt.scatter(xdata,ydata,marker='+',color='blue')
    plt.ylabel('Market Cap')
    plt.xlabel(xlabel)
        
plt.subplot(2,3,1)
plot_data(newdf.btc_market_price, newdf['btc_trade_volume'],'btc_market_price')
plt.subplot(2,3,2)
plot_data(newdf.btc_total_bitcoins, newdf['btc_trade_volume'],'btc_total_bitcoins')
plt.subplot(2,3,3)
plot_data(newdf.btc_market_cap, newdf['btc_trade_volume'],'btc_market_cap')
plt.subplot(2,3,4)
plot_data(newdf.btc_blocks_size, newdf['btc_trade_volume'],'btc_blocks_size')
plt.subplot(2,3,5)
plot_data(newdf.btc_avg_block_size, newdf['btc_trade_volume'],'btc_avg_block_size')
plt.subplot(2,3,5)
plot_data(newdf.btc_n_orphaned_blocks, newdf['btc_trade_volume'],'btc_n_orphaned_blocks')
plt.subplot(2,3,5)
plot_data(newdf.btc_n_transactions_per_block, newdf['btc_trade_volume'],'btc_n_transactions_per_block')
plt.subplot(2,3,5)
plot_data(newdf.btc_median_confirmation_time, newdf['btc_trade_volume'],'btc_median_confirmation_time')
plt.subplot(2,3,5)
plot_data(newdf.btc_hash_rate, newdf['btc_trade_volume'],'btc_hash_rate')
plt.subplot(2,3,5)
plot_data(newdf.btc_cost_per_transaction_percent, newdf['btc_trade_volume'],'btc_cost_per_transaction_percent')
plt.subplot(2,3,5)
plot_data(newdf.btc_cost_per_transaction, newdf['btc_trade_volume'],'btc_cost_per_transaction')
plt.subplot(2,3,5)
plot_data(newdf.btc_n_unique_addresses, newdf['btc_trade_volume'],'btc_n_unique_addresses')
plt.subplot(2,3,5)
plot_data(newdf.btc_n_transactions_total, newdf['btc_trade_volume'],'btc_n_transactions_total')
plt.subplot(2,3,5)
plot_data(newdf.btc_n_transactions_excluding_popular, newdf['btc_trade_volume'],'btc_n_transactions_excluding_popular')
plt.subplot(2,3,5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# as we can see the Market Cap and Open have a linear relationship

# %%
from sklearn import linear_model

model       = linear_model.LinearRegression()
Open        = newdf[['btc_trade_volume']]
Market_Cap  = newdf['btc_trade_volume']

# %%
# train data using linear regression 
model.fit(Open, btc_trade_volume)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2d7dccfa9d78> in <module>
#       1 # train data using linear regression
# ----> 2 model.fit(Open, btc_trade_volume)
#
# NameError: name 'btc_trade_volume' is not defined

# %%
# Model Score
model.score(Open, Market_Cap)
# Out:
# 0.9999801609861945

# %%
# Fill Missing Data Using linear model prediction 
# and Assign it to new column
open = df[['Open']]
market_cap_predict = model.predict(open) 
df['Market Cap Predict'] = market_cap_predict.astype('int64')
df[df['Market Cap'].isnull()].head()
# Out:
#               Open    High     Low   Close    Volume  Market Cap  \
# Date
# 2017-08-01  294.60  426.11  210.38  380.01  65988800         NaN
# 2017-07-31  346.36  347.82  266.19  294.46   1075960         NaN
# 2017-07-30  385.14  385.14  316.25  345.66    606695         NaN
# 2017-07-29  410.56  423.73  323.73  384.77    737815         NaN
# 2017-07-28  386.65  465.18  217.06  406.05   1230160         NaN
#
#             Market Cap Predict
# Date
# 2017-08-01          4859285818
# 2017-07-31          5716421715
# 2017-07-30          6358611246
# 2017-07-29          6779561681
# 2017-07-28          6383616563

# %% [markdown]
# #### 4. Data Visualization

# %%
# %matplotlib inline
    
plt.subplot(2,3,1)
plt.ylabel('Open')
df.Open.plot()

plt.subplot(2,3,2)
plt.ylabel('High')
df.High.plot()

plt.subplot(2,3,3)
plt.ylabel('Low')
df.Low.plot()

plt.subplot(2,3,4)
plt.ylabel('Close')
df.Close.plot()

plt.subplot(2,3,5)
plt.ylabel('Volume')
df.Volume.plot()

plt.subplot(2,3,6)
plt.ylabel('Market Cap Predict')
df['Market Cap Predict'].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a226bce04485> in <module>
#       3 plt.subplot(2,3,1)
#       4 plt.ylabel('Open')
# ----> 5 df.Open.plot()
#       6
#       7 plt.subplot(2,3,2)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Open'
